# %%
import numpy as nmpy
import pandas as pnda
import matplotlib.pyplot as plot

# %%
#Pilot Connector
noChip = pnda.read_csv('PILOT CONNECTOR/NoChip.csv')
#noChip.head()
noChip.plot(subplots=True, figsize=(18, 18))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7faa01d0b710>,
# ...
#       dtype=object)

# %%
chipFox = pnda.read_csv('PILOT CONNECTOR/pilotFox.csv')
#chipFox.head()
chipFox.plot(subplots=True, figsize=(18, 18))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7faa025a1e10>,
# ...
#       dtype=object)

# %%
chipMason = pnda.read_csv('PILOT CONNECTOR/pilotMason.csv')
#chipMason.head()
chipMason.plot(subplots=True, figsize=(18, 18))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7faa022edac8>,
# ...
#       dtype=object)
