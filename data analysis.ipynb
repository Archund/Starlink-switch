# %%
import numpy as nmpy
import pandas as pnda
import matplotlib.pyplot as plot

# %%
#Pilot Connector
noChip = pnda.read_csv('PILOT CONNECTOR/NoChip.csv')
#noChip.head()
noChip.plot(subplots=True, figsize=(18, 18))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8e918908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c89da90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c854ef0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c812390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c8427f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c7f4c50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c7b20f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c763588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c7635c0>],
#       dtype=object)

# %%
chipFox = pnda.read_csv('PILOT CONNECTOR/pilotFox.csv')
#chipFox.head()
chipFox.plot(subplots=True, figsize=(18, 18))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8bf4d438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c4ddef0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c493278>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c4c06d8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c46eb38>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c41ef98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c3d8438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c38b8d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c38b908>],
#       dtype=object)

# %%
chipMason = pnda.read_csv('PILOT CONNECTOR/pilotMason.csv')
#chipMason.head()
chipMason.plot(subplots=True, figsize=(18, 18))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c21b7b8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c1cc940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c1a0438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c14e898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c17fcf8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c141198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c0f35f8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c0a2a90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7c8c0a2ac8>],
#       dtype=object)
